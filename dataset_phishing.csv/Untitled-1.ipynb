# %% [markdown]
# DATA VISUALIZATION

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\AKHI\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# LINE CHART
# BAR CHART
# PIE CHART

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6] 
y = [10, 20, 30, 40, 50, 60]

plt.figure(figsize=(4, 3))
plt.plot(
    x, y,
    c='red',
    marker='*',
    markeredgecolor='black',  
    markeredgewidth=0.5,
    markerfacecolor='black',
    linestyle='--',
    lw=4,
    label='lines'
)

plt.title('LINE CHART', fontsize=15)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.legend(loc='lower right')
plt.show()

# %%
x = [1, 2, 3, 4, 5, 6] 
y = [10, 20, 330, 40, 350, 50]
plt.plot(x,y,color='orange')

# %%
cate=['A','B','C','D','E']
value=[7,8,5,3,2]
c=['red','blue','pink','yellow']
plt.figure(figsize=(4,5))
plt.pie(value,labels=cate,colors=c,explode=[0,0.1,0,0,0],autopct='%.1f%%')
plt.show()

# %%
x=[1,4,3,4,5]
y=[10,23,35,42,55]
plt.figure(figsize=(5,4))
plt.bar(x,y,color='skyblue',edgecolor='black')
for i,j in enumerate(y):
    plt.text(x[i],j+1,str(j),ha='center')
plt.ylim(0,max(y)+10)
plt.xlim(0,max(x)+10)
plt.show()
